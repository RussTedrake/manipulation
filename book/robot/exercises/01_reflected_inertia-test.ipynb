# %% [markdown]
# # **The Effect of Reflected Inertia on Gain Tuning**

# %%
# python libraries
import mpld3
import numpy as np
from matplotlib import pyplot as plt
from pydrake.all import (
    ConstantVectorSource,
    DiagramBuilder,
    PidController,
    Simulator,
    SymbolicVectorSystem,
    Variable,
    VectorLogSink,
    sin,
)

from manipulation import running_as_notebook
from manipulation.exercises.grader import Grader
from manipulation.exercises.robot.test_reflected_inertia import (
    TestSimplePendulumWithGearbox,
)
from manipulation.utils import RenderDiagram

# enable mpld3 notebook
if running_as_notebook:
    mpld3.enable_notebook()

# %% [markdown]
# ## Problem Description
# You will notice that in the first few weeks of the lecture, we don't think a lot about the full second-order dynamics of the arm (a more complicated version of $F=ma$), although we will come to revisit this later. This problem set helps to understand one of the reasons why we can abstract many manipulation problems kinematically (purely in terms of joint angles and end-effector positions), as opposed to worrying about dynamics (joint torques and inertias). Even before going to the multi-link case, let's think about how we should control the position of a single pendulum.
#
# In this problem you will investigate the role of reflected inertia in position control of a simple pendulum. At the end of the notebook, you will be able to check your work in a simulation environment.
#
# **These are the main steps of the exercise:**
# 1. Write down the state-space dynamics function for the simple pendulum with motor and gearbox.
# 2. Set up a PID Controller to do position control for the simple pendulum.
# 3. Qualitatively answer the difference in behavior between direct-drive and gearbox cases.
#
#
# **Your job for this problem set**
# Will be to do step 1 and 3 of the main steps.

# %% [markdown]
# ## The Simple Pendulum
#
# <img src="https://raw.githubusercontent.com/RussTedrake/manipulation/master/book/figures/exercises/simple_pendulum.png" width="400">
#
# The [simple pendulum](https://underactuated.csail.mit.edu/pend.html) is perhaps the simplest abstraction of a 'manipulator', with the following equation for dynamics:
#
# $$ ml^2 \ddot{q} = -mgl\sin(q) + \tau$$
#
# Let's first write down the dynamics of a pendulum in a first-order form,
# $$\dot{x}=f(x,u)$$
#
# where $x=[q,\dot{q}]^T$ is now our state vector, and our input $u=\tau$.
#
# $$\frac{d}{dt}\begin{bmatrix} q \\ \dot{q} \end{bmatrix}=\begin{bmatrix} \dot{q} \\ (-mgl\sin(q) + \tau) / ml^2 \end{bmatrix}$$
#
# The following function returns $\dot{x}$ given $x,u$, and the parameters.
#
# NOTE: For a sine implementation, we will be using `pydrake`'s `sin` for this problem set instead of the numpy implementation. We've already imported it above, so it is available by simply calling `sin()`. This version will not only support numeric, but also symbolic computation.

# %%
def pendulum_dynamics(x, u, p):
    q = x[0]
    qdot = x[1]
    tau = u[0]
    return [
        qdot,
        ((-p["m"] * p["g"] * p["l"] * sin(q) + tau) / (p["m"] * p["l"] ** 2)),
    ]

# %% [markdown]
# ## System Dynamics
#
# From a systems viewpoint, how should this dynamics be abstracted into a system that we can define inputs and outputs on?
#
# As explained in the lecture notes, we can abstract the dynamics as a "plant" that will tell us what the current state $x$ is, given the torque  $\tau$ into the system. If we were to draw a system diagram of this plant, it would look like:
#
# <img src="https://raw.githubusercontent.com/RussTedrake/manipulation/master/book/figures/exercises/simple_pendulum_diagram.png" width="500">
#
#
# To implement this system in [drake](https://drake.mit.edu), we will be using a [`SymbolicVectorSystem`](https://drake.mit.edu/pydrake/pydrake.systems.primitives.html#pydrake.systems.primitives.SymbolicVectorSystem). This is one of the convenient ways to define a system if you have access to a relatively simple, symbolic form of your dynamics. But these equations will get complicated as we move to the multi-link case!
#
# Note that the output of the system doesn't have to be the state $x$ - it can be a subset of the state, or simply some sensor attached to the pendulum! In this case we will assume full access to the state for feedback (i.e. doing full-state feedback), so we simply set `output=x` as well.

# %%
# Symbolic Variables from pydrake.symbolic
x = [Variable("theta"), Variable("thetadot")]
u = [Variable("tau")]

# Example parameters of pendulum dynamics
p = {"m": 1.0, "g": 9.81, "l": 0.5}  # kg  # m / s^2  # m

# Declaration of a symbolic vector system
system = SymbolicVectorSystem(
    state=x, output=x, input=u, dynamics=pendulum_dynamics(x, u, p)
)

# %% [markdown]
# Note that since this system is deterministic, we can completely predict the future value of the system given the current time, state, and input of the system. Sometimes if our system did something unexpected, we may want to know what those states were so that we can replay the simulation and fix our systems.
#
# To make the simulation completely repeatable, Drake stores all the relevant states and parameters in the [context](https://drake.mit.edu/doxygen_cxx/classdrake_1_1systems_1_1_context.html), which can act like a systematic log.

# %%
context = system.CreateDefaultContext()
print(context)
# Out:
# ::_ Context
# ------------
# Time: 0
# States:
#   2 continuous states
#     0 0

# %% [markdown]
# ## The Simple Pendulum with Motor and Gearbox
#
# In class, we saw that the presence of a physical motor and a gearbox can affect the dynamics significantly.
#
# **Now it's your turn to code!**
#
# Below, you will implement a similar dynamics function for a simple pendulum, which now has a physical motor and a gearbox attached to it.
#
# <img src="https://raw.githubusercontent.com/RussTedrake/manipulation/master/book/figures/exercises/pendulum_with_motor.png" width="700">
#
# In addition to the given parameters of mass (`p["m"]`), gravity (`p["g"]`), and length (`p["l"]`), you will need rotor inertia of the motor $I_m$, as well as the gear ratio, $N$. You can assume these can be accessed by `p["I_m"]` and `p["N"]`.
#
# NOTE: For this model, we want the state, $x = [q, \dot{q}],$ to be the joint angles (not $q_{motor}$), but we want the input, $u = \tau_{motor},$ to be the _motor_ torque.
#
# NOTE: Again, do not use `np.sin`!
#
# HINT: Are the dynamics what you expect when `N=1` (i.e. direct-drive)?

# %%
# Modify this function. you may not change the function name, inputs, or size of the output.


def pendulum_with_motor_dynamics(x, u, p):
    q = x[0]
    qdot = x[1]
    tau_motor = u[0]
    return [
        qdot,
        (
            (-p["m"] * p["g"] * p["l"] * sin(q) + p["N"] * tau_motor)
            / (p["I_m"] * (p["N"] ** 2) + (p["m"] * p["l"] ** 2))
        ),
    ]

# %% [markdown]
# # Test Cases for Student Verification
#
# You can use the following test cases to verify your `pendulum_with_motor_dynamics` function implementation. Run the cell below and submit the outputs to Gradescope for verification.

# %%
# Test Case 1: Basic functionality test
def test_pendulum_function():
    """
    Test your pendulum_with_motor_dynamics function with specific inputs.
    Copy the printed results to submit to Gradescope.
    """

    # Test parameters - same as used in the notebook
    test_params = {"m": 1.0, "l": 0.5, "g": 9.81, "N": 160, "I_m": 3.46e-4}

    print("=== PENDULUM DYNAMICS TEST RESULTS ===")
    print("Copy these results to your Gradescope submission:\n")

    # Test Case 1: Zero state, zero input
    x1 = [0.0, 0.0]  # [q, qdot]
    u1 = [0.0]  # [tau_motor]
    result1 = pendulum_with_motor_dynamics(x1, u1, test_params)
    print(f"Test 1 - x={x1}, u={u1}")
    print(f"Result: [{result1[0]:.8f}, {result1[1]:.8f}]")

    # Test Case 2: Non-zero angle, zero velocity, zero torque
    x2 = [np.pi / 4, 0.0]  # 45 degrees
    u2 = [0.0]
    result2 = pendulum_with_motor_dynamics(x2, u2, test_params)
    print(f"\nTest 2 - x={x2}, u={u2}")
    print(f"Result: [{result2[0]:.8f}, {result2[1]:.8f}]")

    # Test Case 3: Non-zero angle, non-zero velocity, non-zero torque
    x3 = [np.pi / 6, 1.5]  # 30 degrees, 1.5 rad/s
    u3 = [2.0]  # 2 Nm motor torque
    result3 = pendulum_with_motor_dynamics(x3, u3, test_params)
    print(f"\nTest 3 - x={x3}, u={u3}")
    print(f"Result: [{result3[0]:.8f}, {result3[1]:.8f}]")

    # Test Case 4: Direct drive case (N=1)
    test_params_direct = test_params.copy()
    test_params_direct["N"] = 1
    x4 = [np.pi / 3, 0.5]  # 60 degrees, 0.5 rad/s
    u4 = [1.0]
    result4 = pendulum_with_motor_dynamics(x4, u4, test_params_direct)
    print(f"\nTest 4 (Direct Drive N=1) - x={x4}, u={u4}")
    print(f"Result: [{result4[0]:.8f}, {result4[1]:.8f}]")

    # Test Case 5: Upright position
    x5 = [np.pi, 0.0]  # Upright (unstable equilibrium)
    u5 = [0.5]
    result5 = pendulum_with_motor_dynamics(x5, u5, test_params)
    print(f"\nTest 5 (Upright) - x={x5}, u={u5}")
    print(f"Result: [{result5[0]:.8f}, {result5[1]:.8f}]")

    print("\n=== END TEST RESULTS ===")
    print("Submit these numerical results to Gradescope for verification.")


# Run the test
test_pendulum_function()
# Out:
# === PENDULUM DYNAMICS TEST RESULTS ===
# Copy these results to your Gradescope submission:
#
# Test 1 - x=[0.0, 0.0], u=[0.0]
# Result: [0.00000000, 0.00000000]
#
# Test 2 - x=[0.7853981633974483, 0.0], u=[0.0]
# Result: [0.00000000, -0.38082028]
#
# Test 3 - x=[0.5235987755982988, 1.5], u=[2.0]
# Result: [1.50000000, 34.86621064]
#
# Test 4 (Direct Drive N=1) - x=[1.0471975511965976, 0.5], u=[1.0]
# Result: [0.50000000, -12.97346315]
#
# Test 5 (Upright) - x=[3.141592653589793, 0.0], u=[0.5]
# Result: [0.00000000, 8.78387281]
#
# === END TEST RESULTS ===
# Submit these numerical results to Gradescope for verification.

# %%
# Additional verification tests
def advanced_verification_tests():
    """
    Additional tests to check edge cases and physical consistency.
    """
    test_params = {"m": 1.0, "l": 0.5, "g": 9.81, "N": 160, "I_m": 3.46e-4}

    print("=== ADVANCED VERIFICATION TESTS ===")

    # Test: Check if dynamics reduce to simple pendulum when N=1 and I_m→0
    print("1. Consistency check with simple pendulum (N=1, small I_m):")
    test_params_simple = {"m": 1.0, "l": 0.5, "g": 9.81, "N": 1, "I_m": 1e-10}
    x = [np.pi / 4, 0.0]
    u = [1.0]

    # Simple pendulum result (for comparison)
    simple_result = pendulum_dynamics(x, u, test_params_simple)
    motor_result = pendulum_with_motor_dynamics(x, u, test_params_simple)

    print(f"Simple pendulum: [{simple_result[0]:.6f}, {simple_result[1]:.6f}]")
    print(f"Motor pendulum:  [{motor_result[0]:.6f}, {motor_result[1]:.6f}]")
    print(f"Difference: {abs(simple_result[1] - motor_result[1]):.8f}")

    # Test: Effect of gear ratio
    print("\n2. Effect of gear ratio on acceleration:")
    x = [np.pi / 6, 0.0]
    u = [1.0]

    for N_val in [1, 10, 100, 160]:
        test_params["N"] = N_val
        result = pendulum_with_motor_dynamics(x, u, test_params)
        print(f"N={N_val:3d}: acceleration = {result[1]:.6f} rad/s²")

    # Reset N
    test_params["N"] = 160

    # Test: Energy considerations (gravity should always act downward)
    print("\n3. Gravity effect verification:")
    u = [0.0]  # No motor torque
    for angle in [0, np.pi / 4, np.pi / 2, 3 * np.pi / 4]:
        x = [angle, 0.0]
        result = pendulum_with_motor_dynamics(x, u, test_params)
        gravity_accel = result[1]
        expected_sign = "negative" if angle < np.pi / 2 else "positive"
        actual_sign = "negative" if gravity_accel < 0 else "positive"
        print(
            f"Angle={angle:.3f} rad ({angle*180/np.pi:.1f}°): accel={gravity_accel:.6f}, expected {expected_sign}"
        )


# Run advanced tests
advanced_verification_tests()
# Out:
# === ADVANCED VERIFICATION TESTS ===
# 1. Consistency check with simple pendulum (N=1, small I_m):
# Simple pendulum: [0.000000, -9.873435]
# Motor pendulum:  [0.000000, -9.873435]
# Difference: 0.00000000
#
# 2. Effect of gear ratio on acceleration:
# N=  1: acceleration = -5.801970 rad/s²
# N= 10: acceleration = 26.519677 rad/s²
# N=100: acceleration = 26.293127 rad/s²
# N=160: acceleration = 17.298465 rad/s²
#
# 3. Gravity effect verification:
# Angle=0.000 rad (0.0°): accel=0.000000, expected negative
# Angle=0.785 rad (45.0°): accel=-0.380820, expected negative
# Angle=1.571 rad (90.0°): accel=-0.538561, expected positive
# Angle=2.356 rad (135.0°): accel=-0.380820, expected positive

# %%
# Quick Gradescope Submission Format
def gradescope_submission_values():
    """
    Generate specific test values for Gradescope submission.
    Students should copy EXACTLY these numerical results.
    """

    # Fixed parameters for consistent results
    p = {"m": 1.0, "l": 0.5, "g": 9.81, "N": 160, "I_m": 3.46e-4}

    print("=== COPY THESE EXACT VALUES TO GRADESCOPE ===\n")

    # Test cases designed to catch common implementation errors
    test_cases = [
        ([0.0, 1.0], [0.0]),  # Pure velocity, no torque
        ([np.pi / 4, 0.0], [1.0]),  # 45°, with torque
        ([np.pi / 2, 0.5], [2.0]),  # 90°, with velocity and torque
        ([-np.pi / 6, -0.5], [-1.0]),  # Negative values
        ([np.pi, 0.0], [0.0]),  # Upright, no torque
    ]

    for i, (x, u) in enumerate(test_cases, 1):
        result = pendulum_with_motor_dynamics(x, u, p)
        print(f"Test {i}: {result[1]:.10f}")

    print(
        f"\nChecksum (sum of all results): {sum([pendulum_with_motor_dynamics(x, u, p)[1] for x, u in test_cases]):.10f}"
    )
    print("\n=== END GRADESCOPE VALUES ===")


# Generate submission values
gradescope_submission_values()
# Out:
# === COPY THESE EXACT VALUES TO GRADESCOPE ===
#
# Test 1: 0.0000000000
# Test 2: 17.1869253413
# Test 3: 34.5969300365
# Test 4: -17.2984650182
# Test 5: -0.0000000000
#
# Checksum (sum of all results): 34.4853903595
#
# === END GRADESCOPE VALUES ===

# %% [markdown]
# You can check if you got the dynamics correct by running the below autograder.

# %%
Grader.grade_output([TestSimplePendulumWithGearbox], [locals()], "results.json")
Grader.print_test_results("results.json")
# Out:
# Total score is 5/5.
#
# Score for Test state space dynamics is 5/5.

# %% [markdown]
# ## Parameter Setting
#
# Now we have defined the dynamics, we can play around with the parameters. We will try to control a pendulum of endpoint mass `m=1kg`, at length `0.5m`. To make the case more fun, let's base the gear ratio `N` and motor inertia `I_m` from Kuka iiwa [(DLR LWR III)](https://www.dlr.de/rm/en/desktopdefault.aspx/tabid-12464/21732_read-49777 )'s 3rd joint.
#
# The iiwa uses a [harmonic drive](https://en.wikipedia.org/wiki/Strain_wave_gearing) geared 160:1, directly from the [HD Company](https://www.harmonicdrive.net/) , and high-performance frameless motors [RoboDrive ILM](https://www.tq-group.com/en/products/tq-robodrive/) from TQ (originally developed at DLR). We will make an educated guess for what exact models they are using:
#
# - RoboDrive ILM 85, with `I_m=0.61e-4 kg m^2`
# - HD SHF-32-160-2UH-LW, with `I_m=2.85e-4 kg m^2`
#
# The "motor inertia" in the problem is in fact the armature inertia of the motor, as well as the part of the transmission attached to the motor shaft!

# %%
# Add motor and gearbox parameters

p = {
    "N": 160,
    "I_m": 3.46e-4,
    "m": 1.0,  # kg
    "g": 9.81,  # m / s^2
    "l": 0.5,  # m
}

# %% [markdown]
# ## Building a PID Controlled System
#
# Now we have to do some plumbing to simulate the system in [Drake](https://drake.mit.edu). We've defined the plant for our dynamics before, but we need to hook it up to a PID controller to do position control, so we will need another system to act as a controller.
#
# Drake offers a built-in [PID Controller](https://drake.mit.edu/pydrake/pydrake.systems.controllers.html#pydrake.systems.controllers.PidController). The role of the controller is to compute the error based on the current and desired states, and command the input, so it could be abstracted by a system with
# - Input ports: x_now ($x$), x_desired ($x_d$)
# - Output ports: torque command ($\tau_{cmd}$)
#
# Are there any other systems that we need to consider? Let's think about the requirements of what we need to implement. Since we need to command $x_d$, we might want a `Slider` or a `ConstantVectorSource` to do so. Also, we would like to plot the trajectory of the system, so we might need a `Logger` to do this for us.
#
# Before we code and hook everything up, it pays to think about what our diagram will actually look like:
#
# <img src="https://raw.githubusercontent.com/RussTedrake/manipulation/master/book/figures/exercises/system_diagram.png" width="1000">
#
#
#
# Did we get all the systems that we want? Are all the IO ports hooked up to the right places? Seems like we are ready to code!

# %%
def BuildAndSimulate(q_d, pendulum_params, gains, visualize=False):
    # This defines the plant using the pendulum with motor dynamics.
    system = SymbolicVectorSystem(
        state=x,
        output=x,
        input=u,
        dynamics=pendulum_with_motor_dynamics(x, u, pendulum_params),
    )

    kp, ki, kd = gains

    builder = DiagramBuilder()

    # Add all the systems into the diagram
    builder.AddSystem(system)
    logger = builder.AddSystem(VectorLogSink(2))
    pid_controller = builder.AddSystem(PidController([kp], [ki], [kd]))
    desired_state = builder.AddSystem(ConstantVectorSource([q_d, 0.0]))

    # Connect the IO ports of the systems.
    builder.Connect(pid_controller.get_output_port(0), system.get_input_port(0))
    builder.Connect(system.get_output_port(0), logger.get_input_port(0))
    builder.Connect(system.get_output_port(0), pid_controller.get_input_port(0))
    builder.Connect(desired_state.get_output_port(0), pid_controller.get_input_port(1))

    diagram = builder.Build()
    diagram.set_name("diagram")

    # Plot the diagram if visualize is true.
    if visualize and running_as_notebook:
        RenderDiagram(diagram, max_depth=1)

    simulator = Simulator(diagram)
    context = simulator.get_mutable_context()

    # The simulator has three states since the plant has 2, and the PID controller
    # keeps an additional state for the integral term. We set all of them to zero
    # initialization.
    context.SetContinuousState([0.0, 0.0, 0.0])

    return simulator, logger.FindLog(context)

# %% [markdown]
# Now let's visualize the diagram and see if everything is properly connected for simulation. Does this topologically resemble our diagram above?

# %%
gains = [5, 2, 1]
simulator, logger = BuildAndSimulate(0.0, p, gains, visualize=True)

# %% [markdown]
# ## Simulating the Closed-Loop System
#
# We are now ready to simulate our system with motor dynamics! Let's start off with the direct-drive case (i.e. `N=1`).

# %%
q_d = (5.0 / 8.0) * np.pi  # Feel free to play around with different final positions.
gains = [5, 2, 1]  # [P, I, D] gains.
p["N"] = 1
simulator, logger = BuildAndSimulate(q_d, p, gains)

simulator.Initialize()
simulator.AdvanceTo(20.0 if running_as_notebook else 0.1)

time = logger.sample_times()
traj = logger.data()

plt.figure()
plt.plot(time, traj[0, :], "b-")
plt.plot(time, q_d * np.ones(traj.shape[1]), "r--")
plt.xlabel("time (s)")
plt.ylabel("q (rads)")
if running_as_notebook:
    display(mpld3.display())
# Out:
# <style>
#
# </style>
#
# <div id="fig_el15244200f3f581f-679f-4fdf-a554-a13914ec1ee48700246682"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el15244200f3f581f-679f-4fdf-a554-a13914ec1ee48700246682", {"width": 640.0, "height": 480.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-1.0, 21.0], "ylim": [-0.09817477042468103, 2.061670178918302], "xdomain": [-1.0, 21.0], "ydomain": [-0.09817477042468103, 2.061670178918302], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 11, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 11, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el15244204e19cdce-8a73-41e6-94f6-d7378be43ae6", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el1524420ff90a3f3-cc7f-4bee-b228-2eb8176ee081", "color": "#0000FF", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el15244202da50c2b-c581-41f5-9ebe-796eccefb9a6", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}], "paths": [], "markers": [], "texts": [{"text": "time (s)", "position": [0.5, -0.07921476671476674], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el1524420b6dac715-6650-4633-b0fe-a78e4d7f1d24"}, {"text": "q (rads)", "position": [-0.09279793906810037, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el15244204d897ff2-b4f4-4351-ae21-47b2c840bfb2"}], "collections": [], "images": [], "sharex": [], "sharey": []}], "data": {"data01": [[0.0, 0.0, 1.9634954084936207], [0.0001, 1.960546754166416e-07, 1.9634954084936207], [0.0006000000000000001, 7.05373677202755e-06, 1.9634954084936207], [0.0031000000000000003, 0.00018772904585096756, 1.9634954084936207], [0.010734430799696661, 0.002229910082726275, 1.9634954084936207], [0.01836886159939332, 0.006466084141712342, 1.9634954084936207], [0.02600329239908998, 0.012827592384957018, 1.9634954084936207], [0.03363772319878664, 0.021242993769782614, 1.9634954084936207], [0.0412721539984833, 0.03163830432323478, 1.9634954084936207], [0.04890658479817996, 0.0439372361877884, 1.9634954084936207], [0.05654101559787662, 0.05806143638874933, 1.9634954084936207], [0.06586768836918347, 0.07767647367764269, 1.9634954084936207], [0.07519436114049032, 0.09974649762672005, 1.9634954084936207], [0.08452103391179716, 0.12411926499681823, 1.9634954084936207], [0.09580741110406486, 0.15647142330655686, 1.9634954084936207], [0.10709378829633256, 0.19169253631616961, 1.9634954084936207], [0.11838016548860027, 0.2295040499246728, 1.9634954084936207], [0.12966654268086797, 0.26962726427260203, 1.9634954084936207], [0.14095291987313568, 0.31178494017763814, 1.9634954084936207], [0.1522392970654034, 0.35570286373644366, 1.9634954084936207], [0.16352567425767112, 0.4011113551533987, 1.9634954084936207], [0.17481205144993883, 0.44774670663378074, 1.9634954084936207], [0.18493427594301612, 0.49040464681123497, 1.9634954084936207], [0.1950565004360934, 0.533663961237777, 1.9634954084936207], [0.2051787249291707, 0.5773517312553784, 1.9634954084936207], [0.21530094942224798, 0.6213018429590584, 1.9634954084936207], [0.22440275179945793, 0.660914216051556, 1.9634954084936207], [0.23350455417666788, 0.7005001353621076, 1.9634954084936207], [0.24260635655387783, 0.7399548170530901, 1.9634954084936207], [0.2517081589310878, 0.7791789603225854, 1.9634954084936207], [0.26080996130829776, 0.8180788837244835, 1.9634954084936207], [0.26991176368550773, 0.8565666203075255, 1.9634954084936207 ...

# %% [markdown]
# You might have noticed that the closed-loop system is unstable for some desired joint configurations. For the gains above, if we ask the controller to stabilize to an upright position (do a swing-up), then the controller seems to be having trouble stabilizing.
#
# Let's try to analyze this effect a bit more systematically by plotting how the state behaves depending on how we set the desired position.

# %%
plt.figure()
p["N"] = 1

q_d_lst = np.linspace(-np.pi, np.pi, 10)
for i in range(len(q_d_lst)):
    simulator, logger = BuildAndSimulate(q_d_lst[i], p, gains)

    simulator.Initialize()
    simulator.AdvanceTo(20.0 if running_as_notebook else 0.1)

    time = logger.sample_times()
    traj = logger.data()

    plt.plot(time, traj[0, :], "b--")
    plt.plot(time, q_d_lst[i] * np.ones(traj.shape[1]), "r--")

plt.xlabel("time (s)")
plt.ylabel("q (rads)")
if running_as_notebook:
    display(mpld3.display())
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1524420d3c53818-6952-455a-87e4-29c03dee13102726778261"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1524420d3c53818-6952-455a-87e4-29c03dee13102726778261", {"width": 640.0, "height": 480.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-1.0, 21.0], "ylim": [-4.908476616981754, 4.908476616981754], "xdomain": [-1.0, 21.0], "ydomain": [-4.908476616981754, 4.908476616981754], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 11, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 7, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el152442058f5d223-8356-4aaa-9134-80536fa7677b", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el1524420a33c4635-a63a-419d-9268-3c55847aa5e8", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el15244207db7475c-6a0f-4e0c-80ee-cda6f4e8630f", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el1524420711adfe8-6726-4aeb-805b-80a8a88b643d", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el152442078f32410-bbec-4ce4-94db-4923b52e1f39", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el1524420d4bfd179-1576-4658-8dd2-6ce455f671db", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el15244203333f8e9-9453-40dc-a1ca-74e0f95ed0d3", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data04", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el152442046afd968-abcb-4a87-8fc5-f7bcd77a0ebe", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data04", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el152442062c6ed82-d57a-4805-a7b4-0e220afb18ce", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data05", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el1524420aeb2df3a-aa48-4d9f-a1bc-14a0ebdd5907", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data05", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el1524420c809f5d7-cb33-402d-be8a-10bb0a687db8", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data05", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el1524420d445d4f7-49a0-42c8-9296-72c2868866ad", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data05", "xindex": 0, "yindex": 4, "coordinates": "data", "id": "el15244202d294430-0eaf-40ae-9d5f-69a0ab78da83", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el1524420c6d0ac07-1a79-48f3-9423-6c242a4965e4", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data06", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el1524420b1fe9a78-3f2f-4b3a-8aa6-bf89375488cc ...

# %% [markdown]
# Note how that the system not only destabilizes for more upright positions, but also shows **different behavior** depending on what angle we ask it to stabilize to. Lower angles don't have overshoots, while higher angles do.
#
# This speaks to the effect of the nonlinear, state-dependent gravity term
# $-mgl\sin(q)$.

# %% [markdown]
# ## Testing out Gearbox Case
#
# Now we will test the same dynamics with a high gear ratio of `N=160`, with the same gains.

# %%
q_d = np.pi / 1  # Feel free to play around with different gains.
gains = [5, 2, 1]  # [P, I, D] gains
p["N"] = 160
simulator, logger = BuildAndSimulate(q_d, p, gains)

simulator.Initialize()
simulator.AdvanceTo(20.0 if running_as_notebook else 0.1)

time = logger.sample_times()
traj = logger.data()

plt.figure()
plt.plot(time, traj[0, :], "b-")
plt.plot(time, q_d * np.ones(traj.shape[1]), "r--")
plt.xlabel("time (s)")
plt.ylabel("q (rads)")
if running_as_notebook:
    display(mpld3.display())
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1524420ff1188a4-2788-4477-8b98-46df24d867a05550668226"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1524420ff1188a4-2788-4477-8b98-46df24d867a05550668226", {"width": 640.0, "height": 480.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-1.0, 21.0], "ylim": [-0.1680787958897556, 3.5296547136848675], "xdomain": [-1.0, 21.0], "ydomain": [-0.1680787958897556, 3.5296547136848675], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 11, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 10, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el15244203c6c5534-6d0e-434f-937a-49a4ed4d0e51", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el1524420c27e7689-a5e9-4fa4-b10b-f3c7734a93d3", "color": "#0000FF", "linewidth": 1.5, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el1524420ddd0399d-a128-49f9-9952-e92a56fc21af", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}], "paths": [], "markers": [], "texts": [{"text": "time (s)", "position": [0.5, -0.07921476671476674], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "hanging", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el152442083ee53eb-7dbe-4075-9915-38ba7bdf1411"}, {"text": "q (rads)", "position": [-0.0751568100358423, 0.5], "coordinates": "axes", "h_anchor": "middle", "v_baseline": "auto", "rotation": -90.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el15244201a892988-ab07-4d58-bf35-bba1549ad63e"}], "collections": [], "images": [], "sharex": [], "sharey": []}], "data": {"data01": [[0.0, 0.0, 3.141592653589793], [0.0001, 1.3789779311663276e-06, 3.141592653589793], [0.0006000000000000001, 4.9501244717050714e-05, 3.141592653589793], [0.002552350535847783, 0.0008857880882454356, 3.141592653589793], [0.004504701071695566, 0.0027286242573300065, 3.141592653589793], [0.006457051607543349, 0.005544268818676052, 3.141592653589793], [0.008409402143391132, 0.009299795738313837, 3.141592653589793], [0.010361752679238915, 0.013963077063357665, 3.141592653589793], [0.012314103215086698, 0.019502766415054815, 3.141592653589793], [0.014266453750934481, 0.0258882827879741, 3.141592653589793], [0.016218804286782264, 0.033089794650269365, 3.141592653589793], [0.018171154822630046, 0.04107820434003312, 3.141592653589793], [0.020123505358477827, 0.04982513275283132, 3.141592653589793], [0.02207585589432561, 0.05930290431558172, 3.141592653589793], [0.02402820643017339, 0.06948453224200683, 3.141592653589793], [0.02598055696602117, 0.08034370406495818, 3.141592653589793], [0.027932907501868953, 0.09185476744097174, 3.141592653589793], [0.029885258037716734, 0.10399271622247627, 3.141592653589793], [0.03183760857356452, 0.116733176793136, 3.141592653589793], [0.0337899591094123, 0.13005239466186758, 3.141592653589793], [0.03574230964526008, 0.14392722131112948, 3.141592653589793], [0.03769466018110786, 0.15833510129513811, 3.141592653589793], [0.039647010716955644, 0.1732540595837219, 3.141592653589793], [0.041599361252803425, 0.18866268914757958, 3.141592653589793], [0.04355171178865121, 0.2045401387807653, 3.141592653589793], [0.04550406232449899, 0.22086610115627722, 3.141592653589793], [0.04745641286034677, 0.23762080111068234, 3.141592653589793], [0.04940876339619455, 0.25478498415376444, 3.141592653589793], [0.05136111393204233, 0.27233990519923745, 3.141592653589793], [0.05331346446789011, 0.2902673175126212, 3.141592653589793], [0.055667191584265814, 0.3123503802607576, 3.141592653589793], [0.058020918700641515, 0.3349188522483467, 3.141592653589793], [0 ...

# %% [markdown]
# Observe that with the same gains, the controller stabilizes is now able to stabilize to an upright position! Let's plot this over a range of different final joint positions as well.

# %%
plt.figure()
p["N"] = 160

q_d_lst = np.linspace(-np.pi, np.pi, 10)
for i in range(len(q_d_lst)):
    simulator, logger = BuildAndSimulate(q_d_lst[i], p, gains)

    simulator.Initialize()
    simulator.AdvanceTo(20.0 if running_as_notebook else 0.1)

    time = logger.sample_times()
    traj = logger.data()

    plt.plot(time, traj[0, :], "b--")
    plt.plot(time, q_d_lst[i] * np.ones(traj.shape[1]), "r--")

plt.xlabel("time (s)")
plt.ylabel("q (rads)")
if running_as_notebook:
    display(mpld3.display())
# Out:
# <style>
#
# </style>
#
# <div id="fig_el152442068e70d28-653a-41af-9a1a-362dbf04ff505961862349"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el152442068e70d28-653a-41af-9a1a-362dbf04ff505961862349", {"width": 640.0, "height": 480.0, "axes": [{"bbox": [0.125, 0.10999999999999999, 0.775, 0.77], "xlim": [-1.0, 21.0], "ylim": [-3.6977335095746233, 3.6977335095746233], "xdomain": [-1.0, 21.0], "ydomain": [-3.6977335095746233, 3.6977335095746233], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 11, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 9, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el152442040833f12-d034-40ac-89e3-dbc8ec2211e6", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el1524420c917db03-509c-48af-a8b4-1972be577a2d", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el1524420be1c77da-516a-46b5-af71-320382e472cc", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el1524420fe59218e-80f0-45bc-a3f2-8dc709dcaaa4", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el15244207a6febff-337e-4673-9b5d-5b94a6565925", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el1524420425ffc5d-9455-4d34-aa52-9612a5232522", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data03", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el1524420d18a140e-3952-4e0e-8e7d-548112b1afa2", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data04", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el15244205cfdc472-46dc-4f0b-91a9-708861ac7f64", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data04", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el1524420e28b5b49-6e94-459b-b671-281880f36c28", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data05", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el1524420e027e787-6d0b-4a73-a5a5-8e4fb880ebc3", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data05", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el1524420ed9dfabb-f0db-4f99-928f-d73fe2be2e9c", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data05", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el1524420449e5f93-fe94-44d9-9f62-dbe3c838c96e", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data05", "xindex": 0, "yindex": 4, "coordinates": "data", "id": "el15244201f9017f8-46d8-42f2-94c1-0bbe23fce114", "color": "#FF0000", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data06", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el152442093850bbf-4412-4879-b535-580b9e72675a", "color": "#0000FF", "linewidth": 1.5, "dasharray": "6,6", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data06", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el15244207a0736cf-7bd3-4cf7-bc37-48ca8d7c ...

# %% [markdown]
# This is looking great! Now we are able to stabilize to most configurations. But not only did we achieve stability, but observe how **consistent** the curves are regardless of what joint configuration we ask it to stabilize to.
#
# You will notice that with a higher gain, we might be able to achieve stability for the direct-drive case as well since we impose no torque bounds. But you are still likely to see that gravity affects the direct-drive case more than the gearbox case.

# %% [markdown]
# ## Qualitative Problem ##
#
# Below, we have a question for you:
#
# **Why are we seeing such consistent behavior of closed-loop dynamics for the gearbox case, as opposed to the direct-drive case?**
#
# You can answer in words using 3-5 sentences.

# %% [markdown]
# ## Your Answer
#
# Submit your response to the above question in the Gradescope 'written submission' section!

# %% [markdown]
# ## How will this notebook be Graded?
#
# If you are enrolled in the class, this notebook will be graded using [Gradescope](www.gradescope.com). You should have gotten the enrollement code on our announcement in Piazza.
#
# For submission of this assignment, you must do two things.
# - Download and submit the notebook `reflected_inertia.ipynb` to Gradescope's notebook submission section, along with your notebook for the second problem.
# - Copy and Paste your answer to the qualitative problem to Gradescope's written submission section.
#
# We will evaluate the local functions in the notebook to see if the function behaves as we have expected. For this exercise, the rubric is as follows:
# - [5 pts] `pendulum_with_motor_dynamics` must be implemented correctly
# - [5 pts] You must answer correctly on why the gearbox and direct-drive cases show different qualitative behavior.
